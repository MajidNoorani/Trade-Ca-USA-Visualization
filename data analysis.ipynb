# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
import json
import os
from tqdm import tqdm

# %%
df = pd.read_csv('Processed/Canadian domestic exports.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.fillna(0, inplace=True)
# df_unpivot = pd.read_csv('Processed/Canadian domestic exports_unpivot.csv')

# %%
dates = df.columns.drop(['origin', 'data_type', 'destination', 'industry', 'code_Naics'])
dates = dates.insert(0, dates[-1])
dates = dates.delete(-1)

# %%
months = set(dates.map(lambda x: x.split(' ')[1]))

# %% [markdown]
# ## ydata- profiling

# %%
profile = ProfileReport(df, title="Profiling Report")
profile.to_file("Canadian domestic exports.html")

# %% [markdown]
# # find trends

# %% [markdown]
# ### xxxxxx codes - Total all countries

# %%
df_total = df[df['origin'] == 'Total All Countries']

# %%
# calculating mean
df_total['mean'] = df_total[dates].mean(axis=1)
# Out:
# /tmp/ipykernel_333001/1965643245.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total['mean'] = df_total[months].mean(axis=1)

# %%
# finding the rows that have value above mean
above_mean_total = {}
for date in dates:
    greater_than = df_total[date].gt(df_total['mean'])
    above_mean_total[date] = df_total[greater_than][['destination', 'industry', 'code_Naics']]

# %% [markdown]
# ## xxxxxx codes - subtotal

# %%
df_subtotal = df[df['origin'] == 'Sub-Total']
# calculating mean
df_subtotal['mean_sub'] = df_subtotal[date].mean(axis=1)
# Out:
# /tmp/ipykernel_333001/2711053643.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subtotal['mean'] = df_subtotal[months].mean(axis=1)

# %%
# finding rows with value below mean
below_mean_sub = {}
for date in dates:
    lower_than = df_subtotal[date].lt(df_subtotal['mean_sub'])
    below_mean_sub[date] = df_subtotal[lower_than][['destination', 'industry', 'code_Naics']]

# %%
below_mean_sub
# Out:
# {'2021 Jan':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  19      West Virginia               sanitary paper product manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  36             Nevada                  motor and generator manufacturing
#  ...               ...                                                ...
#  116805    Connecticut       other transportation equipment manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  13          311930
#  19          322291
#  26          326191
#  36          335312
#  ...            ...
#  116805      336990
#  116817      336310
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [12687 rows x 3 columns],
#  '2021 Feb':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  19      West Virginia               sanitary paper product manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  36             Nevada                  motor and generator manufacturing
#  ...               ...                                                ...
#  116779          Idaho  other plate work and fabricated structural pro...
#  116786    Mississippi            wood container and pallet manufacturing
#  116794        Montana           manufactured (mobile) home manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  13          311930
#  19          322291
#  26          326191
#  36          335312
#  ...            ...
#  116779      332319
#  116786      321920
#  116794      321991
#  116817      336310
#  116841      334220
#
#  [10477 rows x 3 columns],
#  '2021 Mar':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  19      West Virginia               sanitary paper product manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  67               Utah                       granite mining and quarrying
#  ...               ...                                                ...
#  116747  Massachusetts  non-ferrous metal (except aluminum) smelting a...
#  116779          Idaho  other plate work and fabricated structural pro...
#  116794        Montana           manufactured (mobile) home manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  13          311930
#  19          322291
#  26          326191
#  67          212314
#  ...            ...
#  116747      331410
#  116779      332319
#  116794      321991
#  116817      336310
#  116841      334220
#
#  [8979 rows x 3 columns],
#  '2021 Apr':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  19      West Virginia               sanitary paper product manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  45           Michigan                          logging (except contract)
#  ...               ...                                                ...
#  116805    Connecticut       other transportation equipment manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  13          311930
#  19          322291
#  26          326191
#  45          113311
#  ...            ...
#  116805      336990
#  116817      336310
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [9416 rows x 3 columns],
#  '2021 May':          destination                                           industry  \
#  7         Washington                      other clothing knitting mills
#  45          Michigan                          logging (except contract)
#  57          New York  other engine and power transmission equipment ...
#  62          Kentucky                          logging (except contract)
#  67              Utah                       granite mining and quarrying
#  ...              ...                                                ...
#  116769  Pennsylvania               construction machinery manufacturing
#  116805   Connecticut       other transportation equipment manufacturing
#  116822     Tennessee                                         apiculture
#  116831    New Mexico           small electrical appliance manufacturing
#  116841    New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  45          113311
#  57          333619
#  62          113311
#  67          212314
#  ...            ...
#  116769      333120
#  116805      336990
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [9382 rows x 3 columns],
#  '2021 June':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  19      West Virginia               sanitary paper product manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  45           Michigan                          logging (except contract)
#  76           Virginia               animal (except poultry) slaughtering
#  ...               ...                                                ...
#  116794        Montana           manufactured (mobile) home manufacturing
#  116805    Connecticut       other transportation equipment manufacturing
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  19          322291
#  26          326191
#  45          113311
#  76          311611
#  ...            ...
#  116794      321991
#  116805      336990
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [9141 rows x 3 columns],
#  '2021 Jul':          destination                                           industry  \
#  7         Washington                      other clothing knitting mills
#  26              Iowa             plastic plumbing fixture manufacturing
#  36            Nevada                  motor and generator manufacturing
#  45          Michigan                          logging (except contract)
#  57          New York  other engine and power transmission equipment ...
#  ...              ...                                                ...
#  116794       Montana           manufactured (mobile) home manufacturing
#  116817  North Dakota  motor vehicle gasoline engine and engine parts...
#  116822     Tennessee                                         apiculture
#  116831    New Mexico           small electrical appliance manufacturing
#  116841    New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  26          326191
#  36          335312
#  45          113311
#  57          333619
#  ...            ...
#  116794      321991
#  116817      336310
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [9440 rows x 3 columns],
#  '2021 Aug':           destination                                           industry  \
#  36             Nevada                  motor and generator manufacturing
#  45           Michigan                          logging (except contract)
#  67               Utah                       granite mining and quarrying
#  76           Virginia               animal (except poultry) slaughtering
#  97             Kansas                               petroleum refineries
#  ...               ...                                                ...
#  116747  Massachusetts  non-ferrous metal (except aluminum) smelting a...
#  116769   Pennsylvania               construction machinery manufacturing
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  36          335312
#  45          113311
#  67          212314
#  76          311611
#  97          324110
#  ...            ...
#  116747      331410
#  116769      333120
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [8887 rows x 3 columns],
#  '2021 Sep':           destination                                           industry  \
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  36             Nevada                  motor and generator manufacturing
#  45           Michigan                          logging (except contract)
#  57           New York  other engine and power transmission equipment ...
#  ...               ...                                                ...
#  116779          Idaho  other plate work and fabricated structural pro...
#  116794        Montana           manufactured (mobile) home manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  13          311930
#  26          326191
#  36          335312
#  45          113311
#  57          333619
#  ...            ...
#  116779      332319
#  116794      321991
#  116817      336310
#  116822      112910
#  116841      334220
#
#  [8877 rows x 3 columns],
#  '2021 Oct':           destination                                           industry  \
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  36             Nevada                  motor and generator manufacturing
#  57           New York  other engine and power transmission equipment ...
#  67               Utah                       granite mining and quarrying
#  81               Iowa                               hunting and trapping
#  ...               ...                                                ...
#  116786    Mississippi            wood container and pallet manufacturing
#  116794        Montana           manufactured (mobile) home manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  13          311930
#  36          335312
#  57          333619
#  67          212314
#  81          114210
#  ...            ...
#  116786      321920
#  116794      321991
#  116817      336310
#  116822      112910
#  116841      334220
#
#  [8611 rows x 3 columns],
#  '2021 Nov':           destination                                           industry  \
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  19      West Virginia               sanitary paper product manufacturing
#  45           Michigan                          logging (except contract)
#  57           New York  other engine and power transmission equipment ...
#  67               Utah                       granite mining and quarrying
#  ...               ...                                                ...
#  116779          Idaho  other plate work and fabricated structural pro...
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  13          311930
#  19          322291
#  45          113311
#  57          333619
#  67          212314
#  ...            ...
#  116779      332319
#  116817      336310
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [8538 rows x 3 columns],
#  '2021 Dec':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  57           New York  other engine and power transmission equipment ...
#  67               Utah                       granite mining and quarrying
#  81               Iowa                               hunting and trapping
#  ...               ...                                                ...
#  116805    Connecticut       other transportation equipment manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  13          311930
#  57          333619
#  67          212314
#  81          114210
#  ...            ...
#  116805      336990
#  116817      336310
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [9451 rows x 3 columns],
#  '2022 Jan':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  19      West Virginia               sanitary paper product manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  62           Kentucky                          logging (except contract)
#  ...               ...                                                ...
#  116805    Connecticut       other transportation equipment manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  13          311930
#  19          322291
#  26          326191
#  62          113311
#  ...            ...
#  116805      336990
#  116817      336310
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [9469 rows x 3 columns],
#  '2022 Feb':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  36             Nevada                  motor and generator manufacturing
#  45           Michigan                          logging (except contract)
#  ...               ...                                                ...
#  116794        Montana           manufactured (mobile) home manufacturing
#  116805    Connecticut       other transportation equipment manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  13          311930
#  26          326191
#  36          335312
#  45          113311
#  ...            ...
#  116794      321991
#  116805      336990
#  116817      336310
#  116822      112910
#  116841      334220
#
#  [9475 rows x 3 columns],
#  '2022 Mar':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  62           Kentucky                          logging (except contract)
#  67               Utah                       granite mining and quarrying
#  ...               ...                                                ...
#  116805    Connecticut       other transportation equipment manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  13          311930
#  26          326191
#  62          113311
#  67          212314
#  ...            ...
#  116805      336990
#  116817      336310
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [7061 rows x 3 columns],
#  '2022 Apr':           destination                                           industry  \
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  45           Michigan                          logging (except contract)
#  57           New York  other engine and power transmission equipment ...
#  62           Kentucky                          logging (except contract)
#  ...               ...                                                ...
#  116716     Washington              all other miscellaneous manufacturing
#  116731     California          seafood product preparation and packaging
#  116769   Pennsylvania               construction machinery manufacturing
#  116779          Idaho  other plate work and fabricated structural pro...
#  116822      Tennessee                                         apiculture
#
#          code_Naics
#  13          311930
#  26          326191
#  45          113311
#  57          333619
#  62          113311
#  ...            ...
#  116716      339990
#  116731      311710
#  116769      333120
#  116779      332319
#  116822      112910
#
#  [7924 rows x 3 columns],
#  '2022 May':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  19      West Virginia               sanitary paper product manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  62           Kentucky                          logging (except contract)
#  ...               ...                                                ...
#  116805    Connecticut       other transportation equipment manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  13          311930
#  19          322291
#  26          326191
#  62          113311
#  ...            ...
#  116805      336990
#  116817      336310
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [7135 rows x 3 columns],
#  '2022 June':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  19      West Virginia               sanitary paper product manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  62           Kentucky                          logging (except contract)
#  67               Utah                       granite mining and quarrying
#  ...               ...                                                ...
#  116794        Montana           manufactured (mobile) home manufacturing
#  116805    Connecticut       other transportation equipment manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#
#          code_Naics
#  7           315190
#  19          322291
#  26          326191
#  62          113311
#  67          212314
#  ...            ...
#  116794      321991
#  116805      336990
#  116817      336310
#  116822      112910
#  116831      335210
#
#  [7335 rows x 3 columns],
#  '2022 Jul':           destination                                           industry  \
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  57           New York  other engine and power transmission equipment ...
#  62           Kentucky                          logging (except contract)
#  67               Utah                       granite mining and quarrying
#  ...               ...                                                ...
#  116786    Mississippi            wood container and pallet manufacturing
#  116805    Connecticut       other transportation equipment manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  13          311930
#  26          326191
#  57          333619
#  62          113311
#  67          212314
#  ...            ...
#  116786      321920
#  116805      336990
#  116817      336310
#  116822      112910
#  116841      334220
#
#  [7955 rows x 3 columns],
#  '2022 Aug':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  62           Kentucky                          logging (except contract)
#  67               Utah                       granite mining and quarrying
#  ...               ...                                                ...
#  116794        Montana           manufactured (mobile) home manufacturing
#  116805    Connecticut       other transportation equipment manufacturing
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#  116841     New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  13          311930
#  26          326191
#  62          113311
#  67          212314
#  ...            ...
#  116794      321991
#  116805      336990
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [7485 rows x 3 columns],
#  '2022 Sep':           destination                                        industry  \
#  13      Massachusetts  flavouring syrup and concentrate manufacturing
#  45           Michigan                       logging (except contract)
#  62           Kentucky                       logging (except contract)
#  67               Utah                    granite mining and quarrying
#  81               Iowa                            hunting and trapping
#  ...               ...                                             ...
#  116786    Mississippi         wood container and pallet manufacturing
#  116794        Montana        manufactured (mobile) home manufacturing
#  116805    Connecticut    other transportation equipment manufacturing
#  116822      Tennessee                                      apiculture
#  116831     New Mexico        small electrical appliance manufacturing
#
#          code_Naics
#  13          311930
#  45          113311
#  62          113311
#  67          212314
#  81          114210
#  ...            ...
#  116786      321920
#  116794      321991
#  116805      336990
#  116822      112910
#  116831      335210
#
#  [7469 rows x 3 columns],
#  '2022 Oct':           destination                                           industry  \
#  13      Massachusetts     flavouring syrup and concentrate manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  57           New York  other engine and power transmission equipment ...
#  62           Kentucky                          logging (except contract)
#  67               Utah                       granite mining and quarrying
#  ...               ...                                                ...
#  116747  Massachusetts  non-ferrous metal (except aluminum) smelting a...
#  116757           Iowa       other transportation equipment manufacturing
#  116779          Idaho  other plate work and fabricated structural pro...
#  116786    Mississippi            wood container and pallet manufacturing
#  116822      Tennessee                                         apiculture
#
#          code_Naics
#  13          311930
#  26          326191
#  57          333619
#  62          113311
#  67          212314
#  ...            ...
#  116747      331410
#  116757      336990
#  116779      332319
#  116786      321920
#  116822      112910
#
#  [6801 rows x 3 columns],
#  '2022 Nov':           destination                                           industry  \
#  19      West Virginia               sanitary paper product manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  62           Kentucky                          logging (except contract)
#  67               Utah                       granite mining and quarrying
#  81               Iowa                               hunting and trapping
#  ...               ...                                                ...
#  116738   South Dakota  iron and steel mills and ferro-alloy manufactu...
#  116747  Massachusetts  non-ferrous metal (except aluminum) smelting a...
#  116794        Montana           manufactured (mobile) home manufacturing
#  116822      Tennessee                                         apiculture
#  116831     New Mexico           small electrical appliance manufacturing
#
#          code_Naics
#  19          322291
#  26          326191
#  62          113311
#  67          212314
#  81          114210
#  ...            ...
#  116738      331110
#  116747      331410
#  116794      321991
#  116822      112910
#  116831      335210
#
#  [7595 rows x 3 columns],
#  '2022 Dec':           destination                                           industry  \
#  7          Washington                      other clothing knitting mills
#  19      West Virginia               sanitary paper product manufacturing
#  26               Iowa             plastic plumbing fixture manufacturing
#  45           Michigan                          logging (except contract)
#  62           Kentucky                          logging (except contract)
#  ...               ...                                                ...
#  116747  Massachusetts  non-ferrous metal (except aluminum) smelting a...
#  116786    Mississippi            wood container and pallet manufacturing
#  116794        Montana           manufactured (mobile) home manufacturing
#  116817   North Dakota  motor vehicle gasoline engine and engine parts...
#  116822      Tennessee                                         apiculture
#
#          code_Naics
#  7           315190
#  19          322291
#  26          326191
#  45          113311
#  62          113311
#  ...            ...
#  116747      331410
#  116786      321920
#  116794      321991
#  116817      336310
#  116822      112910
#
#  [8638 rows x 3 columns],
#  '2023 Jan':         destination                                           industry  \
#  7        Washington                      other clothing knitting mills
#  26             Iowa             plastic plumbing fixture manufacturing
#  62         Kentucky                          logging (except contract)
#  67             Utah                       granite mining and quarrying
#  76         Virginia               animal (except poultry) slaughtering
#  ...             ...                                                ...
#  116794      Montana           manufactured (mobile) home manufacturing
#  116805  Connecticut       other transportation equipment manufacturing
#  116822    Tennessee                                         apiculture
#  116831   New Mexico           small electrical appliance manufacturing
#  116841   New Mexico  radio and television broadcasting and wireless...
#
#          code_Naics
#  7           315190
#  26          326191
#  62          113311
#  67          212314
#  76          311611
#  ...            ...
#  116794      321991
#  116805      336990
#  116822      112910
#  116831      335210
#  116841      334220
#
#  [9586 rows x 3 columns]}

# %% [markdown]
# ## Comparing

# %%
from tqdm import tqdm

# %%
# finds the rows with value above mean for all countries and the rows with value below mean for Canada
found_rows = {}
for key in tqdm(above_mean_total.keys()):
    dict_total = above_mean_total[key]
    dict_subtotal = below_mean_sub[key]
    for des in dict_total['destination'].unique():
        for code in dict_total[dict_total['destination'] == des]['code_Naics']:
            temp = dict_subtotal[dict_subtotal['destination'] == des]
            temp = temp[temp['code_Naics']==code]
            columns_list = temp.columns.tolist()
            # create a list of values in each column
            values_list = [temp[column].tolist() for column in columns_list]
            output_list = [[a, b, c] for a, b, c in zip(*values_list)]
            if key not in found_rows.keys():
                found_rows[key] = []
            found_rows[key].append(output_list)

# %%
# found rows cotains many empty lists. 
# with this code we remove them
for key in found_rows.keys():
    found_rows[key] = list(filter(lambda x: x, found_rows[key]))

# %%
found_rows['2021 Jan'][:4]
# Out:
# [[['Kentucky',
#    'butter, cheese, and dry and condensed dairy product manufacturing',
#    311515]],
#  [['Kentucky', 'breakfast cereal manufacturing', 311230]],
#  [['Kentucky', 'oil and gas extraction (except oil sands)', 211110]],
#  [['Kentucky', 'dry pea and bean farming', 111130]]]

# %%
with open('Processed/rows_with_lower_export.json', 'w') as f:
    json.dump(found_rows, f)

# %%
# checking if a phenomenon happened periodicaly
years = ['2021', '2022', '2023']
all_common_structured = {}
for month in months:
    year_month = []
    same_periods = []
    for key in found_rows.keys():
        if month in key:
            same_periods.append(found_rows[key])
    # print(same_periods)
    for e in same_periods[0]:
        # print(e)
        flag = 0
        for lists in same_periods[1:]:
            # for e1 in lists:
            #     print(e1)
            #     print("---")
            if e in lists:
                flag = 1
            else:
                flag = 0
                break
        if flag ==1:
            if e[0][0] not in all_common_structured.keys():
                all_common_structured[e[0][0]] = {}
            if e[0][1] not in all_common_structured[e[0][0]].keys():
                all_common_structured[e[0][0]][e[0][1]] = []
            all_common_structured[e[0][0]][e[0][1]].append(month)
            # print(all_common_structured)

# %%
with open('Processed/rows_with_lower_export_frequent_structured.json', 'w') as f:
    json.dump(all_common_structured, f)

# %% [markdown]
# # Province wise
# we find the destinations and indurstries that have sub-total and Totall all countries values above mean
# and then extract the provinces that have export values below mean

# %%
df['mean'] = df[dates].mean(axis=1)

# %%
a = df[df['origin'].isin(['Total All Countries', 'Sub-Total'])]['2021 Jan'].gt(df['mean'])
b = df[a][['origin','2022 Jan', 'mean', 'destination', 'industry']]
b[(b['destination'] == 'Louisiana')]
# Out:
# Empty DataFrame
# Columns: [origin, 2022 Jan, mean, destination, industry]
# Index: []

# %%
b.destination.unique()
# Out:
# array(['Kentucky', 'Florida', 'California', 'Georgia', 'Kansas',
#        'Indiana', 'Hawaii', 'Arizona', 'Alabama', 'Iowa', 'Alaska',
#        'Colorado', 'Arkansas', 'Idaho', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Illinois'], dtype=object)

# %%
# finding the rows that have value above mean
above_mean_totals = {} #both subtotal and all countries
for date in dates:
    greater_than = df[df['origin'].isin(['Total All Countries', 'Sub-Total'])][date].gt(df['mean'])
    above_mean_totals[date] = df[greater_than][['origin', 'destination', 'industry', 'code_Naics']]

# %%
above_mean_totals['2021 Jan'].destination.unique()
# Out:
# array(['Iowa', 'Nevada', 'Michigan', 'New York', 'Utah', 'Virginia',
#        'Kansas', 'Kentucky', 'Nebraska', 'Vermont', 'Oregon', 'Wisconsin',
#        'Hawaii', 'Washington', 'California', 'Mississippi', 'Maryland',
#        'Texas', 'Indiana', 'Delaware', 'New Hampshire', 'Minnesota',
#        'New Jersey', 'Alaska', 'Tennessee', 'Oklahoma', 'Colorado',
#        'Florida', 'Massachusetts', 'North Carolina', 'Louisiana',
#        'Rhode Island', 'District of Columbia', 'Arizona',
#        'South Carolina', 'Montana', 'North Dakota', 'Missouri', 'Maine',
#        'Pennsylvania', 'Georgia', 'South Dakota', 'Connecticut',
#        'New Mexico', 'Idaho', 'Ohio', 'West Virginia', 'Arkansas',
#        'Puerto Rico', 'Alabama', 'Wyoming',
#        'Other unspecified U.S. State', 'U.S. Virgin Islands', 'Illinois'],
#       dtype=object)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
found_rows = {}
for d in tqdm(above_mean_totals.keys()):
    # we find duplicated rows based on values in destination and industry
    both_totals_above_mean = above_mean_totals[d].duplicated(subset=['destination', 'industry'], keep='last')
    df_temp = above_mean_totals[d][both_totals_above_mean]
    # extracting destination and industry and make a list of them
    values_to_match = df_temp[['destination', 'industry']].to_numpy()
    # selecting all rows with specific destination and industry
    selected_rows = pd.DataFrame()
    for values in values_to_match:
        mask = df['destination'].isin(values) & df['industry'].isin(values)
        selected_rows = pd.concat([selected_rows, df[mask]])
    # only select provinces rows
    selected_rows = selected_rows[~selected_rows['origin'].isin(['Sub-Total', 'Sub-total', 'Others', 'Total All Countries'])]
    lower_than = selected_rows[d].lt(selected_rows['mean'])
    found_rows[d] = selected_rows[lower_than][['origin', 'destination', 'industry','mean']]
# Out:
# 100%|██████████| 25/25 [21:59<00:00, 52.79s/it]

# %%
above_mean_totals.keys()
# Out:
# dict_keys(['2021 Jan', '2021 Feb', '2021 Mar', '2021 Apr', '2021 May', '2021 June', '2021 Jul', '2021 Aug', '2021 Sep', '2021 Oct', '2021 Nov', '2021 Dec', '2022 Jan', '2022 Feb', '2022 Mar', '2022 Apr', '2022 May', '2022 June', '2022 Jul', '2022 Aug', '2022 Sep', '2022 Oct', '2022 Nov', '2022 Dec', '2023 Jan'])

# %%
d = '2021 Jan'
both_totals_above_mean = above_mean_totals[d].duplicated(subset=['destination', 'industry'], keep='last')
df_temp = above_mean_totals[d][both_totals_above_mean]
# extracting destination and industry and make a list of them
values_to_match = df_temp[['destination', 'industry']].to_numpy()

# %%
c = found_rows['2021 Aug']
c[c['origin'] == 'British Columbia'].destination.unique()
# Out:
# array(['California', 'Louisiana', 'Texas', 'Minnesota', 'Georgia',
#        'Washington', 'Florida', 'North Carolina', 'Delaware', 'Michigan',
#        'Vermont', 'Montana', 'Iowa', 'Missouri', 'New Jersey',
#        'New Hampshire', 'Nevada', 'New York', 'Maryland', 'South Dakota',
#        'Tennessee', 'Oklahoma', 'Ohio', 'Alabama', 'South Carolina',
#        'Pennsylvania', 'Indiana', 'Massachusetts', 'Virginia',
#        'Connecticut', 'North Dakota', 'Kentucky', 'New Mexico',
#        'Wisconsin', 'Maine', 'Wyoming', 'West Virginia', 'Oregon',
#        'Kansas', 'District of Columbia', 'Colorado', 'Arkansas',
#        'Rhode Island', 'Idaho', 'Nebraska', 'Arizona', 'Alaska',
#        'Mississippi', 'Other unspecified U.S. State', 'Utah',
#        'Puerto Rico', 'Illinois', 'Hawaii'], dtype=object)

# %%
'Louisiana' in ['Nevada', 'New York', 'Kentucky', 'Oregon', 'Washington', 'Utah',
       'North Dakota', 'Minnesota', 'Massachusetts', 'Wisconsin',
       'Michigan', 'New Jersey', 'Vermont', 'North Carolina',
       'Pennsylvania', 'Texas', 'Oklahoma', 'Louisiana', 'Nebraska',
       'Ohio', 'Tennessee', 'South Carolina', 'West Virginia',
       'South Dakota', 'Puerto Rico', 'Rhode Island', 'Virginia',
       'New Hampshire', 'Mississippi', 'Montana', 'Wyoming', 'Maine',
       'Missouri', 'Maryland', 'New Mexico',
       'Other unspecified U.S. State']
# Out:
# True

# %%
# find rows that happend in all years
# checking if a phenomenon happened periodicaly
years = ['2021', '2022', '2023']
all_common_structured = {} 

for month in months:
    i = 1
    year_month = []
    same_periods = []
    for key in found_rows.keys():
        if month in key:
            same_periods.append(found_rows[key])
    
    if month == 'Jan':
        s1 = pd.merge(same_periods[0], same_periods[1], how='inner', on=['origin', 'destination', 'industry'])
        s2 = pd.merge(same_periods[1], same_periods[2], how='inner', on=['origin', 'destination', 'industry'])
        print(s1)
        if len(s1)< len(s2):
            s1 = s2
            i = 3
    else:
        i = 1
        s1 = same_periods[0]
    try:
        for df1 in same_periods[i:]:
            s1 = pd.merge(s1, df1, how='inner', on=['origin', 'destination', 'industry'])
    except:
        pass
        
    # making a structured dictionary
    for e in s1.to_numpy():
        if e[0] not in all_common_structured.keys():
            all_common_structured[e[0]] = {}
        if e[1] not in all_common_structured[e[0]].keys():
            all_common_structured[e[0]][e[1]] = {}
        if e[2] not in all_common_structured[e[0]][e[1]].keys():
            all_common_structured[e[0]][e[1]][e[2]] = []
        all_common_structured[e[0]][e[1]][e[2]].append(month)
# Out:
#                        origin  destination  \
# 0                 Nova Scotia         Iowa
# 1                     Ontario         Iowa
# 2                Saskatchewan      Arizona
# 3                    Manitoba      Arizona
# 4                     Ontario      Florida
# 5                    Manitoba      Florida
# 6            British Columbia      Florida
# 7                      Quebec     Illinois
# 8        Prince Edward Island     Illinois
# 9                      Quebec        Idaho
# 10           British Columbia        Idaho
# 11               Saskatchewan         Iowa
# 12           British Columbia         Iowa
# 13                     Quebec         Iowa
# 14                    Alberta      Indiana
# 15               Saskatchewan      Indiana
# 16              New Brunswick      Indiana
# 17                Nova Scotia      Indiana
# 18                    Ontario     Illinois
# 19           British Columbia     Illinois
# 20                    Ontario        Idaho
# 21           British Columbia        Idaho
# 22                    Ontario      Arizona
# 23           British Columbia      Arizona
# 24                     Quebec      Arizona
# 25           British Columbia      Florida
# 26              New Brunswick      Florida
# 27                    Ontario      Indiana
# 28                     Quebec         Iowa
# 29                   Manitoba         Iowa
# 30                     Quebec   California
# 31                    Alberta   California
# 32           British Columbia   California
# 33           British Columbia       Alaska
# 34  Newfoundland and Labrador      Florida
# 35                     Quebec      Florida
# 36           British Columbia      Florida
# 37           British Columbia   California
# 38               Saskatchewan   California
# 39                Nova Scotia   California
# 40                   Manitoba   California
# 41                     Quebec      Indiana
# 42                     Quebec      Florida
# 43                   Manitoba      Florida
# 44                    Alberta      Florida
# 45                    Alberta     Arkansas
# 46           British Columbia     Arkansas
# 47                Nova Scotia     Arkansas
# 48                Nova Scotia       Kansas
# 49           British Columbia       Kansas
# 50                     Quebec       Kansas
# 51               Saskatchewan       Kansas
# 52                     Quebec  Connecticut
# 53                     Quebec      Alabama
# 54                   Manitoba      Alabama
# 55           British Columbia      Alabama
# 56           British Columbia         Iowa
# 57                    Alberta         Iowa
# 58       Prince Edward Island         Iowa
# 59                Nova Scotia         Iowa
#
#                                              industry     mean_x     mean_y
# 0                all other miscellaneous crop farming      76.64      76.64
# 1                all other miscellaneous crop farming   13300.12   13300.12
# 2   all other non-metallic mineral mining and quar...     101.12     101.12
# 3   all other non-metallic mineral mining and quar...      52.56      52.56
# 4                    oilseed (except soybean) farming    4216.36    4216.36
# 5                    oilseed (except soybean) farming  102498.36  102498.36
# 6                    oilseed (except soybean) farming     295.76     295.76
# 7                    oilseed (except soybean) farming    9089.84    9089.84
# 8                    oilseed (except soybean) farming     295.00     295.00
# 9                        plastic bottle manufacturing    5409.52    5409.52
# 10                       plastic bottle manufacturing    3999.12    3999.12
# 11                       plastic bottle manufacturing     245.72     245.72
# 12                       plastic bottle manufacturing     315.48     315.48
# 13                       plastic bottle manufacturing     402.36     402.36
# 14  motor vehicle transmission and power train par...    5075.80    5075.80
# 15  motor vehicle transmission and power train par...    4745.52    4745.52
# 16  motor vehicle transmission and power train par...    7399.24    7399.24
# 17  motor vehicle transmission and power train par...      40.04      40.04
# 18               all other miscellaneous crop farming   54868.04   54868.04
# 19               all other miscellaneous crop farming   11746.80   11746.80
# 20               all other miscellaneous crop farming   15017.40   15017.40
# 21               all other miscellaneous crop farming   17755.32   17755.32
# 22                       plastic bottle manufacturing  115175.00  115175.00
# 23                       plastic bottle manufacturing   46145.80   46145.80
# 24                       plastic bottle manufacturing     273.72     273.72
# 25  motor home, travel trailer and camper manufact...   38894.20   38894.20
# 26  motor home, travel trailer and camper manufact...     959.76     959.76
# 27                                sugar manufacturing    1888.84    1888.84
# 28  all other non-metallic mineral mining and quar...    3605.72    3605.72
# 29  all other non-metallic mineral mining and quar...     133.48     133.48
# 30  motor home, travel trailer and camper manufact...  108770.52  108770.52
# 31  motor home, travel trailer and camper manufact...   19408.20   19408.20
# 32  motor home, travel trailer and camper manufact...   95022.12   95022.12
# 33                         gold and silver ore mining   15989.84   15989.84
# 34                       granite mining and quarrying    1002.76    1002.76
# 35                       granite mining and quarrying     452.08     452.08
# 36                       granite mining and quarrying    2107.60    2107.60
# 37               all other miscellaneous crop farming   13658.64   13658.64
# 38               all other miscellaneous crop farming  128241.64  128241.64
# 39               all other miscellaneous crop farming    1727.80    1727.80
# 40               all other miscellaneous crop farming  240866.84  240866.84
# 41              cold-rolled steel shape manufacturing    5423.60    5423.60
# 42                       plastic bottle manufacturing   41397.48   41397.48
# 43                       plastic bottle manufacturing     264.68     264.68
# 44                       plastic bottle manufacturing      74.64      74.64
# 45                  motor and generator manufacturing    2325.48    2325.48
# 46                  motor and generator manufacturing    2150.28    2150.28
# 47                  motor and generator manufacturing     918.28     918.28
# 48  all other non-metallic mineral mining and quar...    4706.00    4706.00
# 49  all other non-metallic mineral mining and quar...    3138.60    3138.60
# 50  all other non-metallic mineral mining and quar...   10789.12   10789.12
# 51  all other non-metallic mineral mining and quar...    1823.96    1823.96
# 52              cold-rolled steel shape manufacturing    2897.04    2897.04
# 53               all other miscellaneous crop farming     386.08     386.08
# 54               all other miscellaneous crop farming   12091.44   12091.44
# 55                   oilseed (except soybean) farming       1.32       1.32
# 56  motor vehicle electrical and electronic equipm...    4146.36    4146.36
# 57  motor vehicle electrical and electronic equipm...     293.84     293.84
# 58  motor vehicle transmission and power train par...    1272.00    1272.00
# 59  motor vehicle transmission and power train par...      24.96      24.96

# %%
with open('Processed/rows_with_lower_export_frequent_structured_provinces.json', 'w') as f:
    json.dump(all_common_structured, f)

# %%
all_common_structured['British Columbia']['Louisiana']
# Out:
# {'all other textile product mills': ['June'],
#  'structural wood product manufacturing': ['June'],
#  'primary production of alumina and aluminum': ['June', 'Aug'],
#  'cutlery and hand tool manufacturing': ['June'],
#  'jewellery and silverware manufacturing': ['Mar'],
#  'copper rolling, drawing, extruding and alloying': ['Mar', 'Jan'],
#  'nonwoven fabric mills': ['Mar'],
#  'plastic bottle manufacturing': ['Mar'],
#  'rubber and plastics industry machinery manufacturing': ['Mar'],
#  'clay building material and refractory manufacturing': ['Mar'],
#  'sporting and athletic goods manufacturing': ['Mar'],
#  'all other food manufacturing': ['Mar'],
#  'seasoning and dressing manufacturing': ['Mar'],
#  'clothing accessories and other clothing manufacturing': ['Oct'],
#  'all other miscellaneous wood product manufacturing': ['Oct'],
#  'polystyrene foam product manufacturing': ['Oct'],
#  'confectionery manufacturing from purchased chocolate': ['Oct', 'Dec', 'Nov'],
#  'chocolate and chocolate confectionery manufacturing from cacao beans': ['Oct',
#   'Nov'],
#  'unlaminated plastic profile shape manufacturing': ['Sep'],
#  'aerospace product and parts manufacturing': ['Sep'],
#  'industrial and commercial fan and blower and air purification equipment manufacturing': ['Sep',
#   'Dec'],
#  'turbine and turbine generator set unit manufacturing': ['Sep', 'Dec'],
#  'plastic film and sheet manufacturing': ['Sep'],
#  'all other miscellaneous animal production': ['Apr'],
#  'cookie and cracker manufacturing': ['Aug', 'Nov'],
#  'wiring device manufacturing': ['Aug'],
#  'aluminum rolling, drawing, extruding and alloying': ['Aug'],
#  'metal valve manufacturing': ['Nov'],
#  'iron and steel pipes and tubes manufacturing from purchased steel': ['Nov'],
#  'plastic window and door manufacturing': ['Nov'],
#  'motor home, travel trailer and camper manufacturing': ['Nov'],
#  'all other basic inorganic chemical manufacturing': ['Nov'],
#  'animal (except poultry) slaughtering': ['Nov'],
#  'fruit and vegetable canning, pickling and drying': ['Nov']}
